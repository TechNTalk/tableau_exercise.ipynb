# %% [markdown]
# ## Step 1: Import Libraries

# %%
import pandas as pd
import plotly.express as px
import sqlalchemy

# %% [markdown]
# ## Step 1B: Upload Data

# %%
df = pd.read_csv('/Users/investmentguy/Tableau_Bonfire_124/class_exercise.ipynb/tuesday_homework/Taylor_Train 2.csv', encoding='utf-8', encoding_errors='replace')
df
# Out:
#                  City        Country                      Venue  \
# 0          Evansville  United States  Roberts Municipal Stadium
# 1           Jonesboro  United States         Convocation Center
# 2           St. Louis  United States           Scottrade Center
# 3          Alexandria  United States  Bishop Ireton High School
# 4    North Charleston  United States  North Charleston Coliseum
# ..                ...            ...                        ...
# 440            Sydney      Australia                ANZ Stadium
# 441          Brisbane      Australia                  The Gabba
# 442          Auckland    New Zealand        Mount Smart Stadium
# 443             Tokyo          Japan                 Tokyo Dome
# 444             Tokyo          Japan                 Tokyo Dome
#
#                  Opening act(s) Attendance (tickets sold / available)  \
# 0    Gloriana\r\nKellie Pickler                         7,463 / 7,463
# 1    Gloriana\r\nKellie Pickler                         7,822 / 7,822
# 2    Gloriana\r\nKellie Pickler                       13,764 / 13,764
# 3    Gloriana\r\nKellie Pickler                                     �
# 4    Gloriana\r\nKellie Pickler                         8,751 / 8,751
# ..                          ...                                   ...
# 440        Charli XCX\r\nBroods                       72,805 / 72,805
# 441        Charli XCX\r\nBroods                       43,907 / 43,907
# 442        Charli XCX\r\nBroods                       35,749 / 35,749
# 443                  Charli XCX                     100,109 / 100,109
# 444                  Charli XCX                     100,109 / 100,109
#
#          Revenue                     Tour
# 0       $360,617            Fearless_Tour
# 1       $340,328            Fearless_Tour
# 2       $650,420            Fearless_Tour
# 3              �            Fearless_Tour
# 4       $398,154            Fearless_Tour
# ..           ...                      ...
# 440   $7,686,564  Reputation_Stadium_Tour
# 441   $4,338,127  Reputation_Stadium_Tour
# 442   $3,617,593  Reputation_Stadium_Tour
# 443  $14,859,847  Reputation_Stadium_Tour
# 444  $14,859,847  Reputation_Stadium_Tour
#
# [445 rows x 7 columns]

# %% [markdown]
# ## Step 2: Clean the Data
# * Normalize the column names
# * Check Data types
# * Check nulls
# * Loop back to types
# * Split fields?
# * Drop columns?
# * Cardinality

# %%
# Normalize the column names
df.columns = df.columns.str.replace(' ', '_').str.strip().str.lower()
df
# Out:
#                  city        country                      venue  \
# 0          Evansville  United States  Roberts Municipal Stadium
# 1           Jonesboro  United States         Convocation Center
# 2           St. Louis  United States           Scottrade Center
# 3          Alexandria  United States  Bishop Ireton High School
# 4    North Charleston  United States  North Charleston Coliseum
# ..                ...            ...                        ...
# 440            Sydney      Australia                ANZ Stadium
# 441          Brisbane      Australia                  The Gabba
# 442          Auckland    New Zealand        Mount Smart Stadium
# 443             Tokyo          Japan                 Tokyo Dome
# 444             Tokyo          Japan                 Tokyo Dome
#
#                  opening_act(s) attendance_(tickets_sold_/_available)  \
# 0    Gloriana\r\nKellie Pickler                         7,463 / 7,463
# 1    Gloriana\r\nKellie Pickler                         7,822 / 7,822
# 2    Gloriana\r\nKellie Pickler                       13,764 / 13,764
# 3    Gloriana\r\nKellie Pickler                                     �
# 4    Gloriana\r\nKellie Pickler                         8,751 / 8,751
# ..                          ...                                   ...
# 440        Charli XCX\r\nBroods                       72,805 / 72,805
# 441        Charli XCX\r\nBroods                       43,907 / 43,907
# 442        Charli XCX\r\nBroods                       35,749 / 35,749
# 443                  Charli XCX                     100,109 / 100,109
# 444                  Charli XCX                     100,109 / 100,109
#
#          revenue                     tour
# 0       $360,617            Fearless_Tour
# 1       $340,328            Fearless_Tour
# 2       $650,420            Fearless_Tour
# 3              �            Fearless_Tour
# 4       $398,154            Fearless_Tour
# ..           ...                      ...
# 440   $7,686,564  Reputation_Stadium_Tour
# 441   $4,338,127  Reputation_Stadium_Tour
# 442   $3,617,593  Reputation_Stadium_Tour
# 443  $14,859,847  Reputation_Stadium_Tour
# 444  $14,859,847  Reputation_Stadium_Tour
#
# [445 rows x 7 columns]

# %%
# Check Data Types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 445 entries, 0 to 444
# Data columns (total 7 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   city                                   445 non-null    object
#  1   country                                445 non-null    object
#  2   venue                                  445 non-null    object
#  3   opening_act(s)                         444 non-null    object
#  4   attendance_(tickets_sold_/_available)  442 non-null    object
#  5   revenue                                442 non-null    object
#  6   tour                                   445 non-null    object
# dtypes: object(7)
# memory usage: 24.5+ KB

# %% [markdown]
# ### Takeways:
# * revenue is listed as an object, will need to remove the dollar sign and ensure dataset is converted to integer
# * attendance_(tickets_sold_/_available) is listed as an object, wiill need to remove one of the duplicate numbers and ensure it is also converted to an integer

# %% [markdown]
# #### Dealing with revenue

# %%
# Removing dollar signs from revenue column
df['revenue'] = df['revenue'].str.replace('$', '').str.replace(',','')

# %%
df
# Out:
#                  city        country                      venue  \
# 0          Evansville  United States  Roberts Municipal Stadium
# 1           Jonesboro  United States         Convocation Center
# 2           St. Louis  United States           Scottrade Center
# 3          Alexandria  United States  Bishop Ireton High School
# 4    North Charleston  United States  North Charleston Coliseum
# ..                ...            ...                        ...
# 440            Sydney      Australia                ANZ Stadium
# 441          Brisbane      Australia                  The Gabba
# 442          Auckland    New Zealand        Mount Smart Stadium
# 443             Tokyo          Japan                 Tokyo Dome
# 444             Tokyo          Japan                 Tokyo Dome
#
#                  opening_act(s) attendance_(tickets_sold_/_available)  \
# 0    Gloriana\r\nKellie Pickler                         7,463 / 7,463
# 1    Gloriana\r\nKellie Pickler                         7,822 / 7,822
# 2    Gloriana\r\nKellie Pickler                       13,764 / 13,764
# 3    Gloriana\r\nKellie Pickler                                     �
# 4    Gloriana\r\nKellie Pickler                         8,751 / 8,751
# ..                          ...                                   ...
# 440        Charli XCX\r\nBroods                       72,805 / 72,805
# 441        Charli XCX\r\nBroods                       43,907 / 43,907
# 442        Charli XCX\r\nBroods                       35,749 / 35,749
# 443                  Charli XCX                     100,109 / 100,109
# 444                  Charli XCX                     100,109 / 100,109
#
#       revenue                     tour
# 0      360617            Fearless_Tour
# 1      340328            Fearless_Tour
# 2      650420            Fearless_Tour
# 3           �            Fearless_Tour
# 4      398154            Fearless_Tour
# ..        ...                      ...
# 440   7686564  Reputation_Stadium_Tour
# 441   4338127  Reputation_Stadium_Tour
# 442   3617593  Reputation_Stadium_Tour
# 443  14859847  Reputation_Stadium_Tour
# 444  14859847  Reputation_Stadium_Tour
#
# [445 rows x 7 columns]

# %%
df['revenue'] = df['revenue'].replace('�', 0)

# %%
df
# Out:
#                  city        country                      venue  \
# 0          Evansville  United States  Roberts Municipal Stadium
# 1           Jonesboro  United States         Convocation Center
# 2           St. Louis  United States           Scottrade Center
# 3          Alexandria  United States  Bishop Ireton High School
# 4    North Charleston  United States  North Charleston Coliseum
# ..                ...            ...                        ...
# 440            Sydney      Australia                ANZ Stadium
# 441          Brisbane      Australia                  The Gabba
# 442          Auckland    New Zealand        Mount Smart Stadium
# 443             Tokyo          Japan                 Tokyo Dome
# 444             Tokyo          Japan                 Tokyo Dome
#
#                  opening_act(s) attendance_(tickets_sold_/_available)  \
# 0    Gloriana\r\nKellie Pickler                         7,463 / 7,463
# 1    Gloriana\r\nKellie Pickler                         7,822 / 7,822
# 2    Gloriana\r\nKellie Pickler                       13,764 / 13,764
# 3    Gloriana\r\nKellie Pickler                                     �
# 4    Gloriana\r\nKellie Pickler                         8,751 / 8,751
# ..                          ...                                   ...
# 440        Charli XCX\r\nBroods                       72,805 / 72,805
# 441        Charli XCX\r\nBroods                       43,907 / 43,907
# 442        Charli XCX\r\nBroods                       35,749 / 35,749
# 443                  Charli XCX                     100,109 / 100,109
# 444                  Charli XCX                     100,109 / 100,109
#
#       revenue                     tour
# 0      360617            Fearless_Tour
# 1      340328            Fearless_Tour
# 2      650420            Fearless_Tour
# 3           0            Fearless_Tour
# 4      398154            Fearless_Tour
# ..        ...                      ...
# 440   7686564  Reputation_Stadium_Tour
# 441   4338127  Reputation_Stadium_Tour
# 442   3617593  Reputation_Stadium_Tour
# 443  14859847  Reputation_Stadium_Tour
# 444  14859847  Reputation_Stadium_Tour
#
# [445 rows x 7 columns]

# %%
# Converting revenue to integer type
df['revenue'] = df['revenue'].astype(int)

# %% [markdown]
# ### Dropping All Nulls

# %%
#Dropping all null values since there were only 3 rows within a few columns
df.dropna(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 441 entries, 0 to 444
# Data columns (total 7 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   city                                   441 non-null    object
#  1   country                                441 non-null    object
#  2   venue                                  441 non-null    object
#  3   opening_act(s)                         441 non-null    object
#  4   attendance_(tickets_sold_/_available)  441 non-null    object
#  5   revenue                                441 non-null    int64
#  6   tour                                   441 non-null    object
# dtypes: int64(1), object(6)
# memory usage: 27.6+ KB

# %% [markdown]
# ### Dealing with attendance_(tickets_sold_/_available)

# %%
# Dropping all rows with unicode symbols
df.drop(df[df['attendance_(tickets_sold_/_available)']== '�'].index, inplace=True)

# %%
# Convert to a list
df['attendance_(tickets_sold_/_available)'] = df['attendance_(tickets_sold_/_available)'].str.split('/')

# %%
df
# Out:
#                  city        country                                 venue  \
# 0          Evansville  United States             Roberts Municipal Stadium
# 1           Jonesboro  United States                    Convocation Center
# 2           St. Louis  United States                      Scottrade Center
# 4    North Charleston  United States             North Charleston Coliseum
# 5        Jacksonville  United States  Jacksonville Veterans Memorial Arena
# ..                ...            ...                                   ...
# 440            Sydney      Australia                           ANZ Stadium
# 441          Brisbane      Australia                             The Gabba
# 442          Auckland    New Zealand                   Mount Smart Stadium
# 443             Tokyo          Japan                            Tokyo Dome
# 444             Tokyo          Japan                            Tokyo Dome
#
#                  opening_act(s) attendance_(tickets_sold_/_available)  \
# 0    Gloriana\r\nKellie Pickler                      [7,463 ,  7,463]
# 1    Gloriana\r\nKellie Pickler                      [7,822 ,  7,822]
# 2    Gloriana\r\nKellie Pickler                    [13,764 ,  13,764]
# 4    Gloriana\r\nKellie Pickler                      [8,751 ,  8,751]
# 5    Gloriana\r\nKellie Pickler                    [11,072 ,  11,072]
# ..                          ...                                   ...
# 440        Charli XCX\r\nBroods                    [72,805 ,  72,805]
# 441        Charli XCX\r\nBroods                    [43,907 ,  43,907]
# 442        Charli XCX\r\nBroods                    [35,749 ,  35,749]
# 443                  Charli XCX                  [100,109 ,  100,109]
# 444                  Charli XCX                  [100,109 ,  100,109]
#
#       revenue                     tour
# 0      360617            Fearless_Tour
# 1      340328            Fearless_Tour
# 2      650420            Fearless_Tour
# 4      398154            Fearless_Tour
# 5      507012            Fearless_Tour
# ..        ...                      ...
# 440   7686564  Reputation_Stadium_Tour
# 441   4338127  Reputation_Stadium_Tour
# 442   3617593  Reputation_Stadium_Tour
# 443  14859847  Reputation_Stadium_Tour
# 444  14859847  Reputation_Stadium_Tour
#
# [406 rows x 7 columns]

# %%
df['attendance_(tickets_sold_/_available)'][0]
# Out:
# ['7,463 ', ' 7,463']

# %%
# Creating new column with unique values from attendance column
new_col = []
for val in df['attendance_(tickets_sold_/_available)']:
    new_col.append(val[0])
df['tickets_sold'] = new_col

# %%
df
# Out:
#                  city        country                                 venue  \
# 0          Evansville  United States             Roberts Municipal Stadium
# 1           Jonesboro  United States                    Convocation Center
# 2           St. Louis  United States                      Scottrade Center
# 4    North Charleston  United States             North Charleston Coliseum
# 5        Jacksonville  United States  Jacksonville Veterans Memorial Arena
# ..                ...            ...                                   ...
# 440            Sydney      Australia                           ANZ Stadium
# 441          Brisbane      Australia                             The Gabba
# 442          Auckland    New Zealand                   Mount Smart Stadium
# 443             Tokyo          Japan                            Tokyo Dome
# 444             Tokyo          Japan                            Tokyo Dome
#
#                  opening_act(s) attendance_(tickets_sold_/_available)  \
# 0    Gloriana\r\nKellie Pickler                      [7,463 ,  7,463]
# 1    Gloriana\r\nKellie Pickler                      [7,822 ,  7,822]
# 2    Gloriana\r\nKellie Pickler                    [13,764 ,  13,764]
# 4    Gloriana\r\nKellie Pickler                      [8,751 ,  8,751]
# 5    Gloriana\r\nKellie Pickler                    [11,072 ,  11,072]
# ..                          ...                                   ...
# 440        Charli XCX\r\nBroods                    [72,805 ,  72,805]
# 441        Charli XCX\r\nBroods                    [43,907 ,  43,907]
# 442        Charli XCX\r\nBroods                    [35,749 ,  35,749]
# 443                  Charli XCX                  [100,109 ,  100,109]
# 444                  Charli XCX                  [100,109 ,  100,109]
#
#       revenue                     tour tickets_sold
# 0      360617            Fearless_Tour       7,463
# 1      340328            Fearless_Tour       7,822
# 2      650420            Fearless_Tour      13,764
# 4      398154            Fearless_Tour       8,751
# 5      507012            Fearless_Tour      11,072
# ..        ...                      ...          ...
# 440   7686564  Reputation_Stadium_Tour      72,805
# 441   4338127  Reputation_Stadium_Tour      43,907
# 442   3617593  Reputation_Stadium_Tour      35,749
# 443  14859847  Reputation_Stadium_Tour     100,109
# 444  14859847  Reputation_Stadium_Tour     100,109
#
# [406 rows x 8 columns]

# %%
#Dropping duplicate column

df = df.drop('attendance_(tickets_sold_/_available)', axis=1)

# %%
df
# Out:
#                  city        country                                 venue  \
# 0          Evansville  United States             Roberts Municipal Stadium
# 1           Jonesboro  United States                    Convocation Center
# 2           St. Louis  United States                      Scottrade Center
# 4    North Charleston  United States             North Charleston Coliseum
# 5        Jacksonville  United States  Jacksonville Veterans Memorial Arena
# ..                ...            ...                                   ...
# 440            Sydney      Australia                           ANZ Stadium
# 441          Brisbane      Australia                             The Gabba
# 442          Auckland    New Zealand                   Mount Smart Stadium
# 443             Tokyo          Japan                            Tokyo Dome
# 444             Tokyo          Japan                            Tokyo Dome
#
#                  opening_act(s)   revenue                     tour  \
# 0    Gloriana\r\nKellie Pickler    360617            Fearless_Tour
# 1    Gloriana\r\nKellie Pickler    340328            Fearless_Tour
# 2    Gloriana\r\nKellie Pickler    650420            Fearless_Tour
# 4    Gloriana\r\nKellie Pickler    398154            Fearless_Tour
# 5    Gloriana\r\nKellie Pickler    507012            Fearless_Tour
# ..                          ...       ...                      ...
# 440        Charli XCX\r\nBroods   7686564  Reputation_Stadium_Tour
# 441        Charli XCX\r\nBroods   4338127  Reputation_Stadium_Tour
# 442        Charli XCX\r\nBroods   3617593  Reputation_Stadium_Tour
# 443                  Charli XCX  14859847  Reputation_Stadium_Tour
# 444                  Charli XCX  14859847  Reputation_Stadium_Tour
#
#     tickets_sold
# 0         7,463
# 1         7,822
# 2        13,764
# 4         8,751
# 5        11,072
# ..           ...
# 440      72,805
# 441      43,907
# 442      35,749
# 443     100,109
# 444     100,109
#
# [406 rows x 7 columns]

# %% [markdown]
# ## Cardinality

# %%
threshold = int(len(df)* .3)

# %%
col_to_drop = []
for col in df.columns:
    if df[col].nunique() >= threshold:
        col_to_drop.append(col)

col_to_drop
# Out:
# ['city', 'venue', 'revenue', 'tickets_sold']

# %% [markdown]
# ## Connect to SQL

# %%
my_conn = f'mysql+pymysql://JoshuaLewis1:Shelfchorus304@127.0.0.1:3306/bonfire_124_schema'

# %%
df.to_sql('taylor_swift_tour', con = my_conn, if_exists='replace', index=False)
# Out:
# 406

# %%
df = pd.read_sql('SELECT * FROM taylor_swift_tour', con= my_conn)
df
# Out:
#                  city        country                                 venue  \
# 0          Evansville  United States             Roberts Municipal Stadium
# 1           Jonesboro  United States                    Convocation Center
# 2           St. Louis  United States                      Scottrade Center
# 3    North Charleston  United States             North Charleston Coliseum
# 4        Jacksonville  United States  Jacksonville Veterans Memorial Arena
# ..                ...            ...                                   ...
# 401            Sydney      Australia                           ANZ Stadium
# 402          Brisbane      Australia                             The Gabba
# 403          Auckland    New Zealand                   Mount Smart Stadium
# 404             Tokyo          Japan                            Tokyo Dome
# 405             Tokyo          Japan                            Tokyo Dome
#
#                  opening_act(s)   revenue                     tour  \
# 0    Gloriana\r\nKellie Pickler    360617            Fearless_Tour
# 1    Gloriana\r\nKellie Pickler    340328            Fearless_Tour
# 2    Gloriana\r\nKellie Pickler    650420            Fearless_Tour
# 3    Gloriana\r\nKellie Pickler    398154            Fearless_Tour
# 4    Gloriana\r\nKellie Pickler    507012            Fearless_Tour
# ..                          ...       ...                      ...
# 401        Charli XCX\r\nBroods   7686564  Reputation_Stadium_Tour
# 402        Charli XCX\r\nBroods   4338127  Reputation_Stadium_Tour
# 403        Charli XCX\r\nBroods   3617593  Reputation_Stadium_Tour
# 404                  Charli XCX  14859847  Reputation_Stadium_Tour
# 405                  Charli XCX  14859847  Reputation_Stadium_Tour
#
#     tickets_sold
# 0         7,463
# 1         7,822
# 2        13,764
# 3         8,751
# 4        11,072
# ..           ...
# 401      72,805
# 402      43,907
# 403      35,749
# 404     100,109
# 405     100,109
#
# [406 rows x 7 columns]

# %% [markdown]
# ### Creating a CSV

# %%
df.to_csv('taylor_swift_tour.csv', index=False)
